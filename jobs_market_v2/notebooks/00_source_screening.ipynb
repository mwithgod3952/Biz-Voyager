# %% [markdown]
# # 0단계 소스 적격성 판정
#
# 공식성, 공개성, 구조 안정성을 기준으로 소스를 `approved`, `candidate`, `rejected`로 나눈다. 애매한 경우는 초반에 버리지 않고 `candidate`로 남겨 리콜을 확보한다.

# %%
from IPython.display import display
import pandas as pd

from jobs_market_v2.pipelines import discover_companies_pipeline, discover_sources_pipeline
from jobs_market_v2.settings import get_paths

paths = get_paths()
company_summary = discover_companies_pipeline()
source_summary = discover_sources_pipeline()
company_summary, source_summary
# Out:
# ({'raw_candidate_count': 31,
#   'discovered_company_count': 12,
#   'non_company_removed_count': 19,
#   'tier_counts': {'대기업': 2,
#    '스타트업': 2,
#    '중견/중소': 2,
#    '공공·연구기관': 2,
#    '외국계 한국법인': 2,
#    '지역기업': 2}},
#  {'approved_source_count': 10,
#   'candidate_source_count': 2,
#   'rejected_source_count': 0,
#   'screened_source_count': 12})

# %%
approved = pd.read_csv(paths.approved_sources_path)
candidate = pd.read_csv(paths.candidate_sources_path)
rejected = pd.read_csv(paths.rejected_sources_path)

display(approved.head())
display(candidate.head())
display(rejected.head())
# Out:
#   company_name company_tier         source_name  \
# 0         삼성전자          대기업          삼성전자 공식 채용
# 1          네이버          대기업             네이버 커리어
# 2           당근         스타트업               당근 채용
# 3       티맥스소프트        중견/중소           티맥스소프트 채용
# 4    한국전자통신연구원      공공·연구기관  한국전자통신연구원 연구채용 RSS
#
#                                           source_url source_type  \
# 0  https://careers.samsung.com/job-feed/data-ai.json    json_api
# 1    https://careers.navercorp.com/jobs/data-ai.html   html_page
# 2        https://career.daangn.com/jobs/data-ai.html   html_page
# 3     https://careers.tmaxsoft.com/jobs/data-ai.html   html_page
# 4   https://recruit.etri.re.kr/rss/research-jobs.xml         rss
#
#   source_bucket          source_domain        official_domain  \
# 0      approved    careers.samsung.com    careers.samsung.com
# 1      approved  careers.navercorp.com  careers.navercorp.com
# 2      approved      career.daangn.com      career.daangn.com
# 3      approved   careers.tmaxsoft.com   careers.tmaxsoft.com
# 4      approved     recruit.etri.re.kr     recruit.etri.re.kr
#
#    official_domain_confidence  source_quality_score  is_official_hint  \
# 0                        0.99                  1.00              True
# 1                        0.99                  0.75              True
# 2                        0.99                  0.75              True
# 3                        0.99                  0.75              True
# 4                        0.99                  1.00              True
#
#   structure_hint discovery_method verification_status  failure_count  \
# 0           json      manual_seed                 미검증              0
# 1           html      manual_seed                 미검증              0
# 2           html      manual_seed                 미검증              0
# 3           html      manual_seed                 미검증              0
# 4            rss      manual_seed                 미검증              0
#
#    last_success_at  last_active_job_count  quarantine_reason  is_quarantined  \
# 0              NaN                      0                NaN           False
# 1              NaN                      0                NaN           False
# 2              NaN                      0                NaN           False
# 3              NaN                      0                NaN           False
# 4              NaN                      0                NaN           False
#
#    reject_reason
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#   company_name company_tier       source_name  \
# 0    한국마이크로소프트     외국계 한국법인  한국마이크로소프트 글로벌 채용
# 1        보쉬코리아     외국계 한국법인   보쉬코리아 공개 공고 RSS
#
#                                           source_url source_type  \
# 0  https://careers.microsoft.com/v2/global/ko-kr/...    json_api
# 1           https://jobs.bosch.co.kr/kr/rss/jobs.xml         rss
#
#   source_bucket          source_domain official_domain  \
# 0     candidate  careers.microsoft.com   microsoft.com
# 1     candidate       jobs.bosch.co.kr     bosch.co.kr
#
#    official_domain_confidence  source_quality_score  is_official_hint  \
# 0                        0.99                   0.7              True
# 1                        0.99                   0.7              True
#
#   structure_hint discovery_method verification_status  failure_count  \
# 0           json      manual_seed                 미검증              0
# 1            rss      manual_seed                 미검증              0
#
#    last_success_at  last_active_job_count  quarantine_reason  is_quarantined  \
# 0              NaN                      0                NaN           False
# 1              NaN                      0                NaN           False
#
#    reject_reason
# 0            NaN
# 1            NaN
# Empty DataFrame
# Columns: [company_name, company_tier, source_name, source_url, source_type, source_bucket, source_domain, official_domain, official_domain_confidence, source_quality_score, is_official_hint, structure_hint, discovery_method, verification_status, failure_count, last_success_at, last_active_job_count, quarantine_reason, is_quarantined, reject_reason]
# Index: []
